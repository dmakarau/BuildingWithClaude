# %%
# Import the reusable helper module
from claude_helpers import client, model, add_user_message, add_assistant_message, chat

# %%
messages = []
add_user_message(messages, "How do I solve 5x + 3= 2 for x?")
system_prompt = """
You are a patient math tutor. 
Do not directly answer the student's question. 
Guide them to a solution step by step. 
If they get stuck, give them a hint.
"""
response = chat(messages, system_prompt = system_prompt)

response
# Out:
# '# Solving 5x + 3 = 2\n\nTo solve for x, isolate it on one side of the equation:\n\n**Step 1:** Subtract 3 from both sides\n- 5x + 3 - 3 = 2 - 3\n- 5x = -1\n\n**Step 2:** Divide both sides by 5\n- 5x/5 = -1/5\n- x = -1/5\n\n**Answer: x = -1/5** (or x = -0.2)\n\nTo check: 5(-1/5) + 3 = -1 + 3 = 2 ✓'
