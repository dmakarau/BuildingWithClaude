# %%
# Import the reusable helper module
from claude_helpers import client, model, add_user_message, add_assistant_message, chat

# %%
messages = []
add_user_message(messages, "Generate a one sentence start-up business idea")

response = chat(messages, temperature = 1.0)

response
# Out:
# 'An AI-powered platform that analyzes your calendar, communication patterns, and work habits to automatically negotiate meeting times, decline low-priority requests, and protect your deep work blocks.'
